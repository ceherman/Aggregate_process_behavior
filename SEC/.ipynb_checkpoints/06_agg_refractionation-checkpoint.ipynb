# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# from IPython.core.display import display, HTML, clear_output
# display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import numpy.polynomial.polynomial as poly
import scipy
from scipy import integrate
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import sys
import os

from addict import Dict
import json

from datetime import timedelta, datetime

# %%
sys.path.append("../")
import plotting as my_plot
import akta

import hplc_data_processing as hplc

# %%
# For ref
file_path_feed = f'./hplc_data/2022-01-11_pafvin_feed/'
data_feed, sample_ids_feed = hplc.load_hplc_data(file_path_feed, shift_baseline_time=5)

# %%
# Load HPLC data
file_path = f'./hplc_data/2022-05-12_agg_re_fractionated/'
data, sample_ids = hplc.load_hplc_data(file_path, shift_baseline_time=5)

# %%
sample_ids
# Out:
# ['PAFVIN_large_labelled_18367',
#  'PAFVIN_small_labelled_18372',
#  'PafvinLConc_18347',
#  'PafvinSConc_18352']

# %% [markdown]
# # Labeled PAFVIN agg.

# %%
fig, ax = my_plot.instantiate_fig(xlabel='Time [min]', ylabel='A280 [mAU]')

for i, s in enumerate(sample_ids[:2]):
    if i == 0:
        label = 'Large agg.'
    else:
        label = 'Small agg.'
    ax.plot(data[s].df.time_min, data[s].df.uv_280, label=label)
    
my_plot.set_layout(fig, ax, legend=True)
plt.savefig('./images/6_refractionation_pafvin_agg_labeled_no_pafvin_feed.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = my_plot.instantiate_fig(xlabel='Time [min]', ylabel='A280 [mAU]')

for i, s in enumerate(sample_ids[:2]):
    if i == 0:
        label = 'Large agg.'
    else:
        label = 'Small agg.'
    ax.plot(data[s].df.time_min, data[s].df.uv_280, label=label)
    
ax.plot(data_feed[sample_ids_feed[0]].df.time_min, data_feed[sample_ids_feed[0]].df.uv_280, label='PAFVIN')

ax.set_xlim(8, 22)
ax.set_ylim(-0.01, 0.1)
my_plot.set_layout(fig, ax, legend=True, fontsize=16)
plt.savefig('./images/6_refractionation_pafvin_agg_labeled_with_pafvin_feed.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# # Unlabeled PAFVIN agg.

# %%
fig, ax = my_plot.instantiate_fig(xlabel='Time [min]', ylabel='A280 [mAU]')

for i, s in enumerate(sample_ids[2:]):
    if i == 0:
        label = 'Large agg.'
    else:
        label = 'Small agg.'
    ax.plot(data[s].df.time_min, data[s].df.uv_280, label=label)
    
my_plot.set_layout(fig, ax, legend=True)
# plt.savefig('./images/6_refractionation_pafvin_agg_unlabeled_no_pafvin_feed.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = my_plot.instantiate_fig(xlabel='Time [min]', ylabel='A280 [mAU]')

for i, s in enumerate(sample_ids[2:]):
    if i == 0:
        label = 'Large agg.'
    else:
        label = 'Small agg.'
    ax.plot(data[s].df.time_min, data[s].df.uv_280, label=label)
    
ax.plot(data_feed[sample_ids_feed[0]].df.time_min, data_feed[sample_ids_feed[0]].df.uv_280, label='PAFVIN')

ax.set_xlim(8, 18)
ax.set_ylim(-0.01, 0.1)
my_plot.set_layout(fig, ax, legend=True, fontsize=16)
# plt.savefig('./images/6_refractionation_pafvin_agg_unlabeled_with_pafvin_feed.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = my_plot.instantiate_fig(xlabel='Time [min]', ylabel='A280 [mAU]')

for i, s in enumerate(sample_ids[2:]):
    if i == 0:
        label = 'Large agg.'
    else:
        label = 'Small agg.'
    ax.plot(data[s].df.time_min, data[s].df.uv_280, label=label)
    
ax.plot(data_feed[sample_ids_feed[0]].df.time_min, data_feed[sample_ids_feed[0]].df.uv_280, label='PAFVIN')

ax.set_xlim(15.6, 17.9)
ax.set_ylim(-0.005, 0.02)

my_plot.set_layout(fig, ax, legend=True, fontsize=16)
plt.savefig('./images/6_refractionation_pafvin_agg_unlabeled_with_pafvin_feed_lmw1_peak.png', dpi=300, bbox_inches='tight')
