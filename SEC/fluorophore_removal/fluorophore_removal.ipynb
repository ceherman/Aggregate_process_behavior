# %%
# %load_ext autoreload
# %autoreload 2

# %%
from IPython.core.display import display, HTML, clear_output
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np
import numpy.polynomial.polynomial as poly
import scipy
from scipy import integrate
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import sys
import os

# %%
sys.path.append("/home/chase/codes/python_functions/")
import plotting as my_plot
import akta

# %%
df_l = akta.load_and_clean_xls(f'./data/CH 2022 06 08 pseudo preparative sec PAFVIN L fluorophore removal.xls')
df_s = akta.load_and_clean_xls(f'./data/CH 2022 06 08 pseudo preparative sec PAFVIN S fluorophore removal.xls')

# %%
fig, ax = my_plot.instantiate_fig(x=8, y=6, xlabel='Volume [ml]', ylabel='A280 [mAU]')
ax.plot(df_l.uv_280_ml, df_l.uv_280_mAU)
ax.set_xlim(0, 38)
my_plot.add_fractions(ax, df_l, text=True, xlim_times=(0, 40))
my_plot.set_layout(fig, ax)
# fig.savefig('./images/Fluorophore_removal_PAFVIN_L.png', dpi=300)

# %%
fig, ax = my_plot.instantiate_fig(x=12, y=6, xlabel='Volume [ml]', ylabel='A280 [mAU]')
ax.plot(df_s.uv_280_ml, df_s.uv_280_mAU)
ax.set_xlim(0, 51)
my_plot.add_fractions(ax, df_s, text=True, xlim_times=(0, 51))
my_plot.set_layout(fig, ax)
# fig.savefig('./images/Fluorophore_removal_PAFVIN_S.png', dpi=300)

# %%
fig, ax = my_plot.instantiate_fig(x=12, y=6, xlabel='Volume [ml]')
ax.set_ylabel('A280 [mAU]', labelpad=10)
ax.plot(df_l.uv_280_ml, df_l.uv_280_mAU, label='Large agg.')
ax.plot(df_s.uv_280_ml, df_s.uv_280_mAU, label='Small agg.')
ax.set_ylim(-7, 80)
ax.set_xlim(0, 51)
my_plot.add_fractions(ax, df_s, text=True, xlim_times=(0, 51))
my_plot.set_layout(fig, ax, legend=True, handlelength=0.8)
fig.savefig('./images/Fluorophore_removal_PAFVIN_both.png', dpi=300, bbox_inches='tight')
fig.savefig('./images/Fluorophore_removal_PAFVIN_both.pdf', bbox_inches='tight')
